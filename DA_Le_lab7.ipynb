# %% [markdown]
# <a href="https://colab.research.google.com/github/SARA3SAEED/more-practice/blob/main/DA_Le_lab7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Recall DataFrame Basics

# %% [markdown]
# Execute the following cell

# %%
import pandas as pd

df = pd.DataFrame({"A": [1, 2, 3, 4, 5, 6],
                   "B": [7, 8, 9, 10, 11, 12],
                   "C": [13, 14, 15, 16, 17, 18],
                   "D": ["a", "a", "a", "b", "b", "b"],
                   "E": ["c", "d", "c", "d", "c", "d"]})

# %% [markdown]
# ## DataFrame attributes

# %% [markdown]
# Display `df` columns and index names

# %%
#your code here
df.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E'], dtype='object')

# %% [markdown]
# ## Play with DataFrame columns

# %% [markdown]
# Put column B in a variable `df_B`. What is the type of this variable?

# %%
#your code here
df_B = df["B"]
type(df_B)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Does the following code change anything? Why?
#
#
# `df_B = df[["B"]]`

# %%
#your code here
df_B = df[["B"]]
type(df_B)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Create a column F filled with 12

# %%
#your code here
df["F"]=12
df
# Out:
#    A   B   C  D  E   F
# 0  1   7  13  a  c  12
# 1  2   8  14  a  d  12
# 2  3   9  15  a  c  12
# 3  4  10  16  b  d  12
# 4  5  11  17  b  c  12
# 5  6  12  18  b  d  12

# %% [markdown]
# Create a DataFrame `df_E_B` containing columns B and E. We want column E to be **before** column B.

# %%
#your code here
df_E_B = df[["E", "B"]]
df_E_B
# Out:
#    E   B
# 0  c   7
# 1  d   8
# 2  c   9
# 3  d  10
# 4  c  11
# 5  d  12

# %% [markdown]
# ## Filter a DataFrame

# %% [markdown]
# Display rows 1 to 3 and columns B, C, D from `df` DataFrame.

# %%
#your code here
df.iloc[1:3 , [1, 2, 3]]
# Out:
#    B   C  D
# 1  8  14  a
# 2  9  15  a

# %% [markdown]
# Why does this line of code cause an error?

# %%
df.iloc[1:3, ["B", "C", "D"]]

# %% [markdown]
# > **Your Answer Here (Double click)**

# %% [markdown]
# ## Boolean Indexing

# %% [markdown]
# Select rows from `df` where the value in column B is greater than or equal to 8.

# %%
#your code here
df[df["B"]>=8]
# Out:
#    A   B   C  D  E   F
# 1  2   8  14  a  d  12
# 2  3   9  15  a  c  12
# 3  4  10  16  b  d  12
# 4  5  11  17  b  c  12
# 5  6  12  18  b  d  12

# %% [markdown]
# Select rows from df where the value in column B is greater than or equal to 8 and the value in column D is equal to "a".

# %%
#your code here
df[(df["B"]>=8) & (df["D"]=="a")]
# Out:
#    A  B   C  D  E   F
# 1  2  8  14  a  d  12
# 2  3  9  15  a  c  12

# %% [markdown]
# What does this line of code do?

# %%
df.loc[df["E"]=="c", "A"] = 8
df
# Out:
#    A   B   C  D  E   F
# 0  8   7  13  a  c  12
# 1  2   8  14  a  d  12
# 2  8   9  15  a  c  12
# 3  4  10  16  b  d  12
# 4  8  11  17  b  c  12
# 5  6  12  18  b  d  12

# %% [markdown]
# ## Operations on DataFrame columns

# %% [markdown]
# Calculate the average of columns A, B and F **by using the pd.DataFrame() [inbuilt function](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.mean.html).**

# %%
#your code here
df[["A", "B", "F"]].mean()
# Out:
# A     6.0
# B     9.5
# F    12.0
# dtype: float64

# %% [markdown]
# What happens if we repeat the previous instruction but pass **axis=1** as parameter to `.mean()`function?

# %%
#your code here
df[["A", "B", "F"]].mean(axis=1)
# Out:
# 0     9.000000
# 1     7.333333
# 2     9.666667
# 3     8.666667
# 4    10.333333
# 5    10.000000
# dtype: float64
