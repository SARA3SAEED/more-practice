# %% [markdown]
# <a href="https://colab.research.google.com/github/SARA3SAEED/more-practice/blob/main/DA_Le_Lab19_3_Weather_API_with_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  ![Emil](data:image/png;base64,...)

# %% [markdown]
# #  OpenWeatherMap API 🌦️

# %% [markdown]
# In this challenge, we will use OpenWeatherMap API to retrieve extract temperature forecasts for any city around the globe 🌡️

# %% [markdown]
# ## Read the documentation

# %% [markdown]
# When presented with a new API to use, your first reflex should be to go straight to the documentation, and figure out the following:
#
# - Does it output JSON?
# - Does this API require authentication? (do I need to sign up to get an API key? Do I need to pay?)
# - Which endpoints can I call? What data does it return?
#
#
#
# (Go back to the `API 101` lecture from week 3 if you are confused about some of the above terms)
#
#
# 👯‍♂️ Buddy time! Go to [OpenWeatherMap API documentation](https://openweathermap.org/api) read it, and try answering those questions. When you are comfortable with what this API is about, you can start working on the challenge.

# %% [markdown]
# ## Authentication (and a small 🎁 from us)

# %% [markdown]
# You might have noticed that OpenWeatherMap requires you to sign up for an API key. Even though OpenWeatherMap offers a [few free API calls](https://openweathermap.org/price), they still want to know how different users consume the API (and track if you hit your API call limit 😜). This is the norm for most APIs out there.
#
#
# You can either:
#
# - Sign up for an API key (which might take 10-20 minutes to get activated)
# - Use a proxy we created for you 👉 https://weather.lewagon.com/. This URL already includes the API key, so you can just replace the host of OpenWeatherMap with the Le Wagon website and skip the API key parameter in your request. For example:
#
# `https://api.openweathermap.org/geo/1.0/direct?q=Barcelona&appid=XXXXXXXXXXX`
#
# becomes:
#
# `https://weather.lewagon.com/geo/1.0/direct?q=Barcelona`
#
# **Note**: make sure to check https://weather.lewagon.com/ to see the documentation on which endpoints are proxied (if you get a Forbidden error copy and paste the link in a new tab!). Try to click on one of the examples displayed to make sure that you can run API calls succesfully.
#
#
# If the endpoint you want to access is not shown, you will need to access it with your own API key instead.

# %% [markdown]
# ## Make some API calls

# %% [markdown]
# ### With the browser

# %% [markdown]
# Have a look at the following link.
#
# <code>https://weather.lewagon.com/geo/1.0/direct?q=Paris</code>
#
# Is it a little hard to read ? If you are using Google Chrome, we recommend you to install the [JSONVue extension](https://chromewebstore.google.com/detail/jsonvue/chklaanhfefbnpoihckbnefhakgolnmc), it will make reading JSON on your browser much easier.
# Once installed, reload the page, and admire the difference !

# %% [markdown]
# ### With Python

# %% [markdown]
# Now it's your turn to code ! \
# Use the `requests`library and load the data for the city of Paris in a variable called `paris_info`and print it. \
# This should look exactly the same as in your browser.

# %% [markdown]
# <details>
#     <summary>Hint 🔍</summary>
#
# Do not copy the whole URL provided above, try to use `params` argument of the `requests.get()`method instead.
#
# </details>

# %%
#your code here
import requests
Response = requests.get("https://weather.lewagon.com/geo/1.0/direct?q=Paris")
paris_info = Response.json()
paris_info
# Out:
# [{'name': 'Paris',
#   'local_names': {'ja': 'パリ',
#    'cs': 'Paříž',
#    'ps': 'پاريس',
#    'es': 'París',
#    'eu': 'Paris',
#    'ht': 'Pari',
#    'ur': 'پیرس',
#    'sh': 'Pariz',
#    'sc': 'Parigi',
#    'pa': 'ਪੈਰਿਸ',
#    'my': 'ပါရီမြို့',
#    'pl': 'Paryż',
#    'tg': 'Париж',
#    'sk': 'Paríž',
#    'la': 'Lutetia',
#    'vi': 'Paris',
#    'el': 'Παρίσι',
#    'hy': 'Փարիզ',
#    'he': 'פריז',
#    'ka': 'პარიზი',
#    'mk': 'Париз',
#    'yi': 'פאריז',
#    'bg': 'Париж',
#    'wo': 'Pari',
#    'no': 'Paris',
#    'kk': 'Париж',
#    'ug': 'پارىژ',
#    'ha': 'Pariis',
#    'bs': 'Pariz',
#    'zu': 'IParisi',
#    'ko': '파리',
#    'af': 'Parys',
#    'so': 'Baariis',
#    'bn': 'প্যারিস',
#    'br': 'Pariz',
#    'sv': 'Paris',
#    'li': 'Paries',
#    'fa': 'پاریس',
#    'ar': 'باريس',
#    'tk': 'Pariž',
#    'fy': 'Parys',
#    'or': 'ପ୍ୟାରିସ',
#    'be': 'Парыж',
#    'is': 'París',
#    'bo': 'ཕ་རི།',
#    'lt': 'Paryžius',
#    'hi': 'पैरिस',
#    'tt': 'Париж',
#    'ne': 'पेरिस',
#    'ca': 'París',
#    'gu': 'પૅરિસ',
#    'lv': 'Parīze',
#    'yo': 'Parisi',
#    'gn': 'Parĩ',
#    'de': 'Paris',
#    'kv': 'Париж',
#    'mr': 'पॅरिस',
#    'oc': 'París',
#    'an': 'París',
#    'co': 'Parighji',
#    'gv': 'Paarys',
#    'et': 'Pariis',
#    'os': 'Париж',
#    'mn': 'Парис',
#    'zh': '巴黎',
#    'cu': 'Парижь',
#    'fi': 'Pariisi',
#    'tl': 'Paris',
#    'km': 'ប៉ារីស',
#    'hu': 'Párizs',
#    'it': 'Parigi',
#    'ta': 'பாரிஸ்',
#    'fr': 'Paris',
#    'wa': 'Paris',
#    'ku': 'Parîs',
#    'ba': 'Париж',
#    'kn': 'ಪ್ಯಾರಿಸ್',
#    'cv': 'Парис',
#    'am': 'ፓሪስ',
#    'nl': 'Parijs',
#    'uz': 'Parij',
#    'ru': 'Париж',
#    'eo': 'Parizo',
#    'ky': 'Париж',
#    'hr': 'Pariz',
#    'uk': 'Париж',
#    'th': 'ปารีส',
#    'mi': 'Parī',
#    'ga': 'Páras',
#    'za': 'Bahliz',
#    'lb': 'Paräis',
#    'sr': 'Париз',
#    'sl': 'Pariz',
#    'gl': 'París',
#    'ml': 'പാരിസ്',
#    'ln': 'Pari',
#    'te': 'పారిస్',
#    'sq': 'Parisi'},
#   'lat': 48.8588897,
#   'lon': 2.3200410217200766,
#   'country': 'FR',
#   'state': 'Ile-de-France'}]

# %% [markdown]
# What is the type of `paris_info`?

# %%
#your code here
type(paris_info)
# Out:
# list

# %% [markdown]
# 🎉 Congratulations, you just made your first API call with Python!

# %% [markdown]
# ### Retrieve specific information

# %% [markdown]
# Using your `paris_info`variable, retrieve the latitude and longitude of Paris and store them in a list named `paris_coordinates`

# %%
#your code here
paris_coordinates = [paris_info[0]['lat'],paris_info[0]['lon']]
paris_coordinates
# Out:
# [48.8588897, 2.3200410217200766]

# %% [markdown]
# Finally, create a `get_coordinates`function that will take a city name as argument and return its coordinates in a list.

# %%
#your code here

def get_coordinates(city):
    Response = requests.get(f"https://weather.lewagon.com/geo/1.0/direct?q={city}")
    city_info = Response.json()
    return [city_info[0]['lat'],city_info[0]['lon']]


get_coordinates('Paris')
# Out:
# [48.8588897, 2.3200410217200766]

# %% [markdown]
# ## Weather Forecasts

# %% [markdown]
# ### Paris forecasts

# %% [markdown]
# Go back to the documentation, and find an endpoint you can use to get weather forecasts data.

# %% [markdown]
# <details>
#     <summary>Hint 🔍</summary>
#
# The proxy provided by Le Wagon has a `forecast` endpoint.
#
# </details>

# %% [markdown]
# What are the `query parameters` we need to get that information? \
# Using that endpoint, store the weather forecasts of Paris in a variable named `paris_forecasts`.

# %% [markdown]
# <details>
#     <summary>Hint 🔍</summary>
#
# You can re-use your `get_coordinates` function.
#
# </details>

# %%
#your code here
paris_coordinates = get_coordinates('Paris')
Response = requests.get(f"https://weather.lewagon.com/data/2.5/forecast?lat={paris_coordinates[0]}&lon={paris_coordinates[1]}")
paris_forecasts = Response.json()
paris_forecasts
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1732125600,
#    'main': {'temp': 277,
#     'feels_like': 273.77,
#     'temp_min': 277,
#     'temp_max': 278.78,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 1000,
#     'humidity': 85,
#     'temp_kf': -1.78},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 75},
#    'wind': {'speed': 3.72, 'deg': 276, 'gust': 9.11},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-20 18:00:00'},
#   {'dt': 1732136400,
#    'main': {'temp': 277.5,
#     'feels_like': 274.85,
#     'temp_min': 277.5,
#     'temp_max': 278.51,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 1002,
#     'humidity': 76,
#     'temp_kf': -1.01},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 73},
#    'wind': {'speed': 3.04, 'deg': 292, 'gust': 7.97},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-20 21:00:00'},
#   {'dt': 1732147200,
#    'main': {'temp': 277.62,
#     'feels_like': 275.92,
#     'temp_min': 277.62,
#     'temp_max': 277.93,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1001,
#     'humidity': 66,
#     'temp_kf': -0.31},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 82},
#    'wind': {'speed': 1.98, 'deg': 292, 'gust': 6.99},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-21 00:00:00'},
#   {'dt': 1732158000,
#    'main': {'temp': 277.72,
#     'feels_like': 276.8,
#     'temp_min': 277.72,
#     'temp_max': 277.72,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 1000,
#     'humidity': 59,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.36, 'deg': 211, 'gust': 2.12},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-21 03:00:00'},
#   {'dt': 1732168800,
#    'main': {'temp': 277.43,
#     'feels_like': 275.05,
#     'temp_min': 277.43,
#     'temp_max': 277.43,
#     'pressure': 1007,
#     'sea_level': 1007,
#     'grnd_level': 997,
#     'humidity': 59,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.67, 'deg': 171, 'gust': 5.74},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-21 06:00:00'},
#   {'dt': 1732179600,
#    'main': {'temp': 275.33,
#     'feels_like': 271.04,
#     'temp_min': 275.33,
#     'temp_max': 275.33,
#     'pressure': 1001,
#     'sea_level': 1001,
#     'grnd_level': 991,
#     'humidity': 84,
#     'temp_kf': 0},
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.86, 'deg': 147, 'gust': 9.96},
#    'visibility': 4915,
#    'pop': 1,
#    'snow': {'3h': 1.09},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-11-21 09:00:00'},
#   {'dt': 1732190400,
#    'main': {'temp': 274.49,
#     'feels_like': 270.34,
#     'temp_min': 274.49,
#     'temp_max': 274.49,
#     'pressure': 994,
#     'sea_level': 994,
#     'grnd_level': 984,
#     'humidity': 99,
#     'temp_kf': 0},
#    'weather': [{'id': 601,
#      'main': 'Snow',
#      'description': 'snow',
#      'icon': '13d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.26, 'deg': 79, 'gust': 9.61},
#    'visibility': 645,
#    'pop': 1,
#    'snow': {'3h': 7.02},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-11-21 12:00:00'},
#   {'dt': 1732201200,
#    'main': {'temp': 274.02,
#     'feels_like': 268.39,
#     'temp_min': 274.02,
#     'temp_max': 274.02,
#     'pressure': 989,
#     'sea_level': 989,
#     'grnd_level': 979,
#     'humidity': 99,
#     'temp_kf': 0},
#    'weather': [{'id': 601,
#      'main': 'Snow',
#      'description': 'snow',
#      'icon': '13d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 6.91, 'deg': 37, 'gust': 13.8},
#    'pop': 1,
#    'snow': {'3h': 6.99},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-11-21 15:00:00'},
#   {'dt': 1732212000,
#    'main': {'temp': 273.98,
#     'feels_like': 268.49,
#     'temp_min': 273.98,
#     'temp_max': 273.98,
#     'pressure': 995,
#     'sea_level': 995,
#     'grnd_level': 985,
#     'humidity': 93,
#     'temp_kf': 0},
#    'weather': [{'id': 601,
#      'main': 'Snow',
#      'description': 'snow',
#      'icon': '13n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 6.56, 'deg': 15, 'gust': 12.94},
#    'visibility': 10000,
#    'pop': 1,
#    'snow': {'3h': 4.13},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-21 18:00:00'},
#   {'dt': 1732222800,
#    'main': {'temp': 272.96,
#     'feels_like': 269.6,
#     'temp_min': 272.96,
#     'temp_max': 272.96,
#     'pressure': 1003,
#     'sea_level': 1003,
#     'grnd_level': 992,
#     'humidity': 90,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.81, 'deg': 326, 'gust': 8.62},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-21 21:00:00'},
#   {'dt': 1732233600,
#    'main': {'temp': 272.98,
#     'feels_like': 270.42,
#     'temp_min': 272.98,
#     'temp_max': 272.98,
#     'pressure': 1006,
#     'sea_level': 1006,
#     'grnd_level': 996,
#     'humidity': 91,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 82},
#    'wind': {'speed': 2.06, 'deg': 247, 'gust': 5.22},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-22 00:00:00'},
#   {'dt': 1732244400,
#    'main': {'temp': 273.26,
#     'feels_like': 269.22,
#     'temp_min': 273.26,
#     'temp_max': 273.26,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 998,
#     'humidity': 83,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.69, 'deg': 239, 'gust': 11.05},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-22 03:00:00'},
#   {'dt': 1732255200,
#    'main': {'temp': 273.99,
#     'feels_like': 270.7,
#     'temp_min': 273.99,
#     'temp_max': 273.99,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 999,
#     'humidity': 95,
#     'temp_kf': 0},
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.95, 'deg': 231, 'gust': 11.22},
#    'visibility': 10000,
#    'pop': 0.32,
#    'snow': {'3h': 0.35},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-22 06:00:00'},
#   {'dt': 1732266000,
#    'main': {'temp': 274.65,
#     'feels_like': 270.22,
#     'temp_min': 274.65,
#     'temp_max': 274.65,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1001,
#     'humidity': 95,
#     'temp_kf': 0},
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13d'}],
#    'clouds': {'all': 97},
#    'wind': {'speed': 4.8, 'deg': 250, 'gust': 11.7},
#    'visibility': 10000,
#    'pop': 1,
#    'snow': {'3h': 0.66},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-11-22 09:00:00'},
#   {'dt': 1732276800,
#    'main': {'temp': 275.77,
#     'feels_like': 271.21,
#     'temp_min': 275.77,
#     'temp_max': 275.77,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 1002,
#     'humidity': 92,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 97},
#    'wind': {'speed': 5.59, 'deg': 249, 'gust': 13.67},
#    'visibility': 10000,
#    'pop': 0.82,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-11-22 12:00:00'},
#   {'dt': 1732287600,
#    'main': {'temp': 276.09,
#     'feels_like': 272.31,
#     'temp_min': 276.09,
#     'temp_max': 276.09,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1005,
#     'humidity': 87,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 47},
#    'wind': {'speed': 4.28, 'deg': 254, 'gust': 11.97},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-11-22 15:00:00'},
#   {'dt': 1732298400,
#    'main': {'temp': 275.32,
#     'feels_like': 271.64,
#     'temp_min': 275.32,
#     'temp_max': 275.32,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1008,
#     'humidity': 86,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 26},
#    'wind': {'speed': 3.84, 'deg': 235, 'gust': 10.7},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-22 18:00:00'},
#   {'dt': 1732309200,
#    'main': {'temp': 275.18,
#     'feels_like': 272.17,
#     'temp_min': 275.18,
#     'temp_max': 275.18,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1010,
#     'humidity': 82,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 87},
#    'wind': {'speed': 2.9, 'deg': 238, 'gust': 9.65},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-22 21:00:00'},
#   {'dt': 1732320000,
#    'main': {'temp': 275.11,
#     'feels_like': 273,
#     'temp_min': 275.11,
#     'temp_max': 275.11,
#     'pressure': 1021,
#     'sea_level': 1021,
#     'grnd_level': 1011,
#     'humidity': 84,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 87},
#    'wind': {'speed': 1.98, 'deg': 221, 'gust': 7.87},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-23 00:00:00'},
#   {'dt': 1732330800,
#    'main': {'temp': 275.06,
#     'feels_like': 272.13,
#     'temp_min': 275.06,
#     'temp_max': 275.06,
#     'pressure': 1022,
#     'sea_level': 1022,
#     'grnd_level': 1012,
#     'humidity': 84,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 61},
#    'wind': {'speed': 2.78, 'deg': 205, 'gust': 9.51},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-23 03:00:00'},
#   {'dt': 1732341600,
#    'main': {'temp': 274.88,
#     'feels_like': 271.64,
#     'temp_min': 274.88,
#     'temp_max': 274.88,
#     'pressure': 1022,
#     'sea_level': 1022,
#     'grnd_level': 1012,
#     'humidity': 89,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 75},
#    'wind': {'speed': 3.11, 'deg': 173, 'gust': 10.39},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-23 06:00:00'},
#   {'dt': 1732352400,
#    'main': {'temp': 275.95,
#     'feels_like': 272.17,
#     'temp_min': 275.95,
#     'temp_max': 275.95,
#     'pressure': 1021,
#     'sea_level': 1021,
#     'grnd_level': 1011,
#     'humidity': 78,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.22, 'deg': 163, 'gust': 13.29},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-11-23 09:00:00'},
#   {'dt': 1732363200,
#    'main': {'temp': 276.59,
#     'feels_like': 272.89,
#     'temp_min': 276.59,
#     'temp_max': 276.59,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1009,
#     'humidity': 77,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.34, 'deg': 164, 'gust': 12.98},
#    'visibility': 10000,
#    'pop': 0.2,
#    'rain': {'3h': 0.17},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-11-23 12:00:00'},
#   {'dt': 1732374000,
#    'main': {'temp': 277.6,
#     'feels_like': 273.67,
#     'temp_min': 277.6,
#     'temp_max': 277.6,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1006,
#     'humidity': 72,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.28, 'deg': 176, 'gust': 16.43},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-11-23 15:00:00'},
#   {'dt': 1732384800,
#    'main': {'temp': 278.07,
#     'feels_like': 274.43,
#     'temp_min': 278.07,
#     'temp_max': 278.07,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1005,
#     'humidity': 79,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.9, 'deg': 182, 'gust': 17.21},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-23 18:00:00'},
#   {'dt': 1732395600,
#    'main': {'temp': 280.08,
#     'feels_like': 276.72,
#     'temp_min': 280.08,
#     'temp_max': 280.08,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1005,
#     'humidity': 76,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.43, 'deg': 194, 'gust': 19.4},
#    'visibility': 10000,
#    'pop': 0.23,
#    'rain': {'3h': 0.19},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-23 21:00:00'},
#   {'dt': 1732406400,
#    'main': {'temp': 280.86,
#     'feels_like': 277.58,
#     'temp_min': 280.86,
#     'temp_max': 280.86,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 1004,
#     'humidity': 74,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.75, 'deg': 194, 'gust': 19.82},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-24 00:00:00'},
#   {'dt': 1732417200,
#    'main': {'temp': 281.9,
#     'feels_like': 278.86,
#     'temp_min': 281.9,
#     'temp_max': 281.9,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 1004,
#     'humidity': 73,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.85, 'deg': 192, 'gust': 20.5},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-24 03:00:00'},
#   {'dt': 1732428000,
#    'main': {'temp': 282.8,
#     'feels_like': 280.01,
#     'temp_min': 282.8,
#     'temp_max': 282.8,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 1004,
#     'humidity': 76,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.82, 'deg': 193, 'gust': 20.12},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-24 06:00:00'},
#   {'dt': 1732438800,
#    'main': {'temp': 284.41,
#     'feels_like': 283.47,
#     'temp_min': 284.41,
#     'temp_max': 284.41,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 1004,
#     'humidity': 72,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 6.26, 'deg': 193, 'gust': 20.37},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-11-24 09:00:00'},
#   {'dt': 1732449600,
#    'main': {'temp': 286.69,
#     'feels_like': 285.77,
#     'temp_min': 286.69,
#     'temp_max': 286.69,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 1003,
#     'humidity': 64,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 6.28, 'deg': 192, 'gust': 19.91},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-11-24 12:00:00'},
#   {'dt': 1732460400,
#    'main': {'temp': 287.13,
#     'feels_like': 286.41,
#     'temp_min': 287.13,
#     'temp_max': 287.13,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 1002,
#     'humidity': 70,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.84, 'deg': 180, 'gust': 19.19},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-11-24 15:00:00'},
#   {'dt': 1732471200,
#    'main': {'temp': 287.37,
#     'feels_like': 286.86,
#     'temp_min': 287.37,
#     'temp_max': 287.37,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1001,
#     'humidity': 77,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 6.44, 'deg': 180, 'gust': 19.77},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-24 18:00:00'},
#   {'dt': 1732482000,
#    'main': {'temp': 286.68,
#     'feels_like': 286.02,
#     'temp_min': 286.68,
#     'temp_max': 286.68,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 1001,
#     'humidity': 74,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 6.16, 'deg': 179, 'gust': 19.83},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-24 21:00:00'},
#   {'dt': 1732492800,
#    'main': {'temp': 286.28,
#     'feels_like': 285.42,
#     'temp_min': 286.28,
#     'temp_max': 286.28,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 999,
#     'humidity': 68,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 7.09, 'deg': 177, 'gust': 21.55},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-25 00:00:00'},
#   {'dt': 1732503600,
#    'main': {'temp': 286.47,
#     'feels_like': 285.61,
#     'temp_min': 286.47,
#     'temp_max': 286.47,
#     'pressure': 1007,
#     'sea_level': 1007,
#     'grnd_level': 998,
#     'humidity': 67,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 7.12, 'deg': 183, 'gust': 21.95},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-25 03:00:00'},
#   {'dt': 1732514400,
#    'main': {'temp': 288.62,
#     'feels_like': 287.82,
#     'temp_min': 288.62,
#     'temp_max': 288.62,
#     'pressure': 1006,
#     'sea_level': 1006,
#     'grnd_level': 996,
#     'humidity': 61,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 7.81, 'deg': 189, 'gust': 22.86},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-25 06:00:00'},
#   {'dt': 1732525200,
#    'main': {'temp': 288.16,
#     'feels_like': 287.73,
#     'temp_min': 288.16,
#     'temp_max': 288.16,
#     'pressure': 1006,
#     'sea_level': 1006,
#     'grnd_level': 996,
#     'humidity': 77,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 8.94, 'deg': 202, 'gust': 23.06},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 0.69},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-11-25 09:00:00'},
#   {'dt': 1732536000,
#    'main': {'temp': 286.37,
#     'feels_like': 285.89,
#     'temp_min': 286.37,
#     'temp_max': 286.37,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 999,
#     'humidity': 82,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 7.37, 'deg': 228, 'gust': 14.02},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 1.92},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-11-25 12:00:00'},
#   {'dt': 1732546800,
#    'main': {'temp': 286.52,
#     'feels_like': 285.58,
#     'temp_min': 286.52,
#     'temp_max': 286.52,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 1001,
#     'humidity': 64,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 69},
#    'wind': {'speed': 6.91, 'deg': 221, 'gust': 14.99},
#    'visibility': 10000,
#    'pop': 0.3,
#    'rain': {'3h': 0.27},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-11-25 15:00:00'}],
#  'city': {'id': 6545270,
#   'name': 'Palais-Royal',
#   'coord': {'lat': 48.8589, 'lon': 2.32},
#   'country': 'FR',
#   'population': 0,
#   'timezone': 3600,
#   'sunrise': 1732086479,
#   'sunset': 1732118711}}

# %% [markdown]
# Starting from your `paris_forecasts` variable and using a for loop, create 2 variables named `times` and `maxs` that will respectively store the forecast datetimes and maximum temperatures of Paris.

# %%
#your code here
times = []
maxs = []
for i in range(len(paris_forecasts['list'])):
    times.append(paris_forecasts['list'][i]['dt_txt'])
    maxs.append(paris_forecasts['list'][i]['main']['temp_max'])

    print(paris_forecasts['list'][i]['dt_txt'])
    print(paris_forecasts['list'][i]['main']['temp_max'])
    print("------")
# Out:
# 2024-11-20 18:00:00
# 278.78
# ------
# 2024-11-20 21:00:00
# 278.51
# ------
# 2024-11-21 00:00:00
# 277.93
# ------
# 2024-11-21 03:00:00
# 277.72
# ------
# 2024-11-21 06:00:00
# 277.43
# ------
# 2024-11-21 09:00:00
# 275.33
# ------
# 2024-11-21 12:00:00
# 274.49
# ------
# 2024-11-21 15:00:00
# 274.02
# ------
# 2024-11-21 18:00:00
# 273.98
# ------
# 2024-11-21 21:00:00
# 272.96
# ------
# 2024-11-22 00:00:00
# 272.98
# ------
# 2024-11-22 03:00:00
# 273.26
# ------
# 2024-11-22 06:00:00
# 273.99
# ------
# 2024-11-22 09:00:00
# 274.65
# ------
# 2024-11-22 12:00:00
# 275.77
# ------
# 2024-11-22 15:00:00
# 276.09
# ------
# 2024-11-22 18:00:00
# 275.32
# ------
# 2024-11-22 21:00:00
# 275.18
# ------
# 2024-11-23 00:00:00
# 275.11
# ------
# 2024-11-23 03:00:00
# 275.06
# ------
# 2024-11-23 06:00:00
# 274.88
# ------
# 2024-11-23 09:00:00
# 275.95
# ------
# 2024-11-23 12:00:00
# 276.59
# ------
# 2024-11-23 15:00:00
# 277.6
# ------
# 2024-11-23 18:00:00
# 278.07
# ------
# 2024-11-23 21:00:00
# 280.08
# ------
# 2024-11-24 00:00:00
# 280.86
# ------
# 2024-11-24 03:00:00
# 281.9
# ------
# 2024-11-24 06:00:00
# 282.8
# ------
# 2024-11-24 09:00:00
# 284.41
# ------
# 2024-11-24 12:00:00
# 286.69
# ------
# 2024-11-24 15:00:00
# 287.13
# ------
# 2024-11-24 18:00:00
# 287.37
# ------
# 2024-11-24 21:00:00
# 286.68
# ------
# 2024-11-25 00:00:00
# 286.28
# ------
# 2024-11-25 03:00:00
# 286.47
# ------
# 2024-11-25 06:00:00
# 288.62
# ------
# 2024-11-25 09:00:00
# 288.16
# ------
# 2024-11-25 12:00:00
# 286.37
# ------
# 2024-11-25 15:00:00
# 286.52
# ------

# %% [markdown]
# Finally, store your 2 lists in a `paris_dict` dictionary, assigning them to 2 keys: `datetime` and `max_temperature`

# %%
#your code here
paris_dict = {'datetime':times,'max_temperature':maxs}
paris_dict
# Out:
# {'datetime': ['2024-11-20 18:00:00',
#   '2024-11-20 21:00:00',
#   '2024-11-21 00:00:00',
#   '2024-11-21 03:00:00',
#   '2024-11-21 06:00:00',
#   '2024-11-21 09:00:00',
#   '2024-11-21 12:00:00',
#   '2024-11-21 15:00:00',
#   '2024-11-21 18:00:00',
#   '2024-11-21 21:00:00',
#   '2024-11-22 00:00:00',
#   '2024-11-22 03:00:00',
#   '2024-11-22 06:00:00',
#   '2024-11-22 09:00:00',
#   '2024-11-22 12:00:00',
#   '2024-11-22 15:00:00',
#   '2024-11-22 18:00:00',
#   '2024-11-22 21:00:00',
#   '2024-11-23 00:00:00',
#   '2024-11-23 03:00:00',
#   '2024-11-23 06:00:00',
#   '2024-11-23 09:00:00',
#   '2024-11-23 12:00:00',
#   '2024-11-23 15:00:00',
#   '2024-11-23 18:00:00',
#   '2024-11-23 21:00:00',
#   '2024-11-24 00:00:00',
#   '2024-11-24 03:00:00',
#   '2024-11-24 06:00:00',
#   '2024-11-24 09:00:00',
#   '2024-11-24 12:00:00',
#   '2024-11-24 15:00:00',
#   '2024-11-24 18:00:00',
#   '2024-11-24 21:00:00',
#   '2024-11-25 00:00:00',
#   '2024-11-25 03:00:00',
#   '2024-11-25 06:00:00',
#   '2024-11-25 09:00:00',
#   '2024-11-25 12:00:00',
#   '2024-11-25 15:00:00'],
#  'max_temperature': [278.78,
#   278.51,
#   277.93,
#   277.72,
#   277.43,
#   275.33,
#   274.49,
#   274.02,
#   273.98,
#   272.96,
#   272.98,
#   273.26,
#   273.99,
#   274.65,
#   275.77,
#   276.09,
#   275.32,
#   275.18,
#   275.11,
#   275.06,
#   274.88,
#   275.95,
#   276.59,
#   277.6,
#   278.07,
#   280.08,
#   280.86,
#   281.9,
#   282.8,
#   284.41,
#   286.69,
#   287.13,
#   287.37,
#   286.68,
#   286.28,
#   286.47,
#   288.62,
#   288.16,
#   286.37,
#   286.52]}

# %% [markdown]
# ### Any city forecasts

# %% [markdown]
# Using every previous step, create a `get_forecasts` function that will take a city name as argument and return a dictionnary containing the forecast datetimes and maximum temperatures. 🚀

# %%
#your code here

def get_forecasts(city):
    coordinates = get_coordinates(city)
    Response = requests.get(f"https://weather.lewagon.com/data/2.5/forecast?lat={coordinates[0]}&lon={coordinates[1]}")
    city_forecasts = Response.json()
    city_forecasts_dict = {'datetime':[],'max_temperature':[]}
    for i in range(len(city_forecasts['list'])):
        city_forecasts_dict['datetime'].append(city_forecasts['list'][i]['dt_txt'])
        city_forecasts_dict['max_temperature'].append(city_forecasts['list'][i]['main']['temp_max'])
    return city_forecasts_dict


get_forecasts('a')
# Out:
# {'datetime': ['2024-11-20 18:00:00',
#   '2024-11-20 21:00:00',
#   '2024-11-21 00:00:00',
#   '2024-11-21 03:00:00',
#   '2024-11-21 06:00:00',
#   '2024-11-21 09:00:00',
#   '2024-11-21 12:00:00',
#   '2024-11-21 15:00:00',
#   '2024-11-21 18:00:00',
#   '2024-11-21 21:00:00',
#   '2024-11-22 00:00:00',
#   '2024-11-22 03:00:00',
#   '2024-11-22 06:00:00',
#   '2024-11-22 09:00:00',
#   '2024-11-22 12:00:00',
#   '2024-11-22 15:00:00',
#   '2024-11-22 18:00:00',
#   '2024-11-22 21:00:00',
#   '2024-11-23 00:00:00',
#   '2024-11-23 03:00:00',
#   '2024-11-23 06:00:00',
#   '2024-11-23 09:00:00',
#   '2024-11-23 12:00:00',
#   '2024-11-23 15:00:00',
#   '2024-11-23 18:00:00',
#   '2024-11-23 21:00:00',
#   '2024-11-24 00:00:00',
#   '2024-11-24 03:00:00',
#   '2024-11-24 06:00:00',
#   '2024-11-24 09:00:00',
#   '2024-11-24 12:00:00',
#   '2024-11-24 15:00:00',
#   '2024-11-24 18:00:00',
#   '2024-11-24 21:00:00',
#   '2024-11-25 00:00:00',
#   '2024-11-25 03:00:00',
#   '2024-11-25 06:00:00',
#   '2024-11-25 09:00:00',
#   '2024-11-25 12:00:00',
#   '2024-11-25 15:00:00'],
#  'max_temperature': [275.09,
#   274.42,
#   273.32,
#   272.29,
#   271.09,
#   272.89,
#   273.97,
#   273.09,
#   271.93,
#   271.77,
#   271.67,
#   271.58,
#   271.24,
#   272.23,
#   272.89,
#   272.4,
#   272.37,
#   272.56,
#   272.69,
#   273.43,
#   273.23,
#   273.12,
#   274.25,
#   273.66,
#   273.26,
#   273.41,
#   274.38,
#   275.2,
#   275.77,
#   276.85,
#   279.93,
#   276.81,
#   275.33,
#   274.76,
#   274.96,
#   274.24,
#   273.85,
#   277.84,
#   280.48,
#   277.3]}

# %% [markdown]
# Congratulations ! 🎉 \
# You have now created a powerful function that can give you hourly temperature forecasts thanks to some API calls !

# %% [markdown]
# ### Bonus : Visualization

# %% [markdown]
# Run the following lines of code to plot the temperature forecasts for various cities accross the globe 🌍 \
# Don't worry about about the `plotly.express` library, we will cover it in the next lecture.

# %%
print(df)
# Out:
#                       Paris  London  Lisbon  New York  Cape Town  Madrid
# datetime
# 2024-11-20 18:00:00  278.78  276.32  289.70    287.43     291.32  287.20
# 2024-11-20 21:00:00  278.51  275.43  289.83    287.36     291.06  286.73
# 2024-11-21 00:00:00  277.93  275.05  289.59    286.66     290.87  285.99
# 2024-11-21 03:00:00  277.72  274.86  289.25    285.88     290.49  284.94
# 2024-11-21 06:00:00  277.43  275.10  288.86    285.48     292.09  283.85
# 2024-11-21 09:00:00  275.33  275.55  289.19    284.32     294.06  284.63
# 2024-11-21 12:00:00  274.49  276.80  290.36    283.75     294.67  287.58
