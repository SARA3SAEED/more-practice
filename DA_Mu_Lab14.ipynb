# %% [markdown]
# <a href="https://colab.research.google.com/github/SARA3SAEED/more-practice/blob/main/DA_Mu_Lab14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas Projects

# %% [markdown]
# ## Ecommerce Purchases EDA Project

# %% [markdown]
# #### Import pandas and read in the csv file

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/DA-Mu/s14/pandas-files/datasets/ecommerce-purchases.csv')

# %% [markdown]
# #### Check the head of the DataFrame

# %%
df.head(2)
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
#
#    CC Security Code   CC Provider               Email  \
# 0               900  JCB 16 digit   pdunlap@yahoo.com
# 1               561    Mastercard  anthony41@reed.com
#
#                                       Job       IP Address Language  \
# 0  Scientist, product/process development  149.146.147.205       el
# 1                       Drilling engineer     15.160.41.51       fr
#
# ...

# %% [markdown]
# #### How many rows and columns are there?

# %%
df.shape
# Out:
# (10000, 14)

# %% [markdown]
# #### What is the average Purchase Price?

# %%
df['Purchase Price'].mean()
# Out:
# 50.347302

# %% [markdown]
# #### What were the highest and lowest purchase prices?

# %%
df['Purchase Price'].max()
# Out:
# 99.99

# %%
df['Purchase Price'].min()
# Out:
# 0.0

# %% [markdown]
# #### How many people have English 'en' as their Language of choice on the website?

# %%
df[df['Language']== 'en']['Email'].count()
# Out:
# 1098

# %% [markdown]
# #### How many people have the job title of "Lawyer" ?

# %%
df[df['Job']== 'Lawyer']['Email'].count()
# Out:
# 30

# %% [markdown]
# #### How many people made the purchase during the AM and how many people made the purchase during PM ?

# %%
df['AM or PM'].value_counts()
# Out:
# AM or PM
# PM    5068
# AM    4932
# Name: count, dtype: int64

# %% [markdown]
# #### What are the 5 most common Job Titles?

# %%
df['Job'].value_counts().head()
# Out:
# Job
# Interior and spatial designer    31
# Lawyer                           30
# Social researcher                28
# Purchasing manager               27
# Designer, jewellery              27
# Name: count, dtype: int64

# %% [markdown]
# #### What is the email of the person with the following Credit Card Number: 4926535242672853

# %%
df[df['Credit Card']== 4926535242672853]['Email']
# Out:
# 1234    bondellen@williams-garza.com
# Name: Email, dtype: object

# %% [markdown]
# #### How many people have American Express as their Credit Card Provider *and made a purchase above  95 USD ?

# %%
df[(df['CC Provider']== 'American Express') &( df['Purchase Price'] > 95)]
# Out:
#                                                 Address    Lot AM or PM  \
# 9       3795 Dawson Extensions\nLake Tinafort, ID 88739  15 Ug       AM
# 280   81060 Dustin Causeway Apt. 503\nPort Danielche...  80 zh       PM
# 372              359 Stanley Coves\nSalasfort, SD 59457  75 Ub       PM
# 677       4855 Peter Bridge\nJohnsonberg, PA 90599-0009  62 Nx       AM
# 766             386 Alisha Unions\nSteelebury, ND 19782  28 pJ       PM
# 1225    916 Amanda Heights\nNew Johnland, CA 52112-8572  09 vg       PM
# 1381  79284 Lisa Mews Suite 069\nKellyborough, CT 71...  45 MR       PM
# 1385  67796 James Keys Suite 656\nSouth Katieshire, ...  06 ia       PM
# 1568       76108 Barker Manors\nEast Amy, PW 49544-5921  82 Qw       AM
# 1727  478 Anita Hill Apt. 766\nAverymouth, FM 50629-...  94 qM       AM
# 2146           557 Barton Harbor\nFuentesport, VI 29961  96 MV       AM
# 2264   040 Ingram Way Suite 602\nEast Matthew, AR 67341  52 WA       AM
# ...

# %% [markdown]
# #### How many people have a credit card that expires in 2025?

# %%
df['Exp Year'] = df['CC Exp Date'].str[-2:]

# %%
df['Exp Year']
# Out:
# 0       20
# 1       18
# 2       19
# 3       24
# 4       25
#         ..
# 9995    22
# 9996    25
# 9997    21
# 9998    17
# 9999    19
# Name: Exp Year, Length: 10000, dtype: object

# %%
count_2025 = df[df['Exp Year'] == '25']
count_2025.head(2)
# Out:
#                                              Address    Lot AM or PM  \
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# 5  7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
#
#                                         Browser Info  \
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
# 5  Mozilla/5.0 (Macintosh; U; PPC Mac OS X 10_8_5...
#
#                      Company       Credit Card CC Exp Date  CC Security Code  \
# 4  Brown, Watson and Andrews  6011456623207998       10/25               678
# 5             Silva-Anderson    30246185196287       07/25              7169
#
#                    CC Provider                        Email  \
# 4  Diners Club / Carte Blanche  christopherwright@gmail.com
# 5                     Discover            ynguyen@gmail.com
#
#                  Job     IP Address Language  Purchase Price Exp Year
# 4        Fine artist   24.140.33.94       es           77.82       25
# ...

# %%
count_2025.shape[0]
# Out:
# 1033

# %%
count_2025 = df[df['Exp Year'] == '25'].shape[0]

# %%
print(f"Number of people with credit cards expiring in 2025: {count_2025}")
# Out:
# Number of people with credit cards expiring in 2025: 1033

# %% [markdown]
# ==========

# %% [markdown]
# ## Weather EDA Project

# %% [markdown]
# #### Import pandas as pd

# %% [markdown]
# #### Read Salaries.csv as a dataframe

# %%
df2 = pd.read_csv('/content/drive/MyDrive/DA-Mu/s14/pandas-files/datasets/weather.csv')

# %% [markdown]
# #### Check the head of the DataFrame

# %%
df2.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %% [markdown]
# #### Use the .info() method to find out how many entries there are

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %% [markdown]
# #### Find all the unique 'Wind Speed' values in the data.

# %%
df2['Wind Speed_km/h'].unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2])

# %% [markdown]
# #### Find the number of times when weather exactly clear.

# %%
df2[df2['Weather'] == 'Clear']['Weather'].count()
# Out:
# 1326

# %% [markdown]
# #### Find the number of times when wind speed was exactly 4km/h.

# %%
df2[df2['Wind Speed_km/h'] == 4]['Wind Speed_km/h'].count()
# Out:
# 474

# %% [markdown]
# #### Find all the null values in the data

# %%
df2.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %% [markdown]
# #### Rename the column name weather of the dataframe to ‘Weather Condition’.

# %%
df2.rename(columns={'Weather': 'Weather Condition'}, inplace=True)

# %% [markdown]
# #### What the average value of ‘visibility’

# %%
df2['Visibility_km'].mean()
# Out:
# 27.664446721311478

# %% [markdown]
# #### What is standard deviation of ‘pressure’ in this data.

# %%
df2['Press_kPa'].std()
# Out:
# 0.8440047459486474

# %% [markdown]
# #### What is variance of ‘Relative Humidity’ in this data.

# %%
df2['Rel Hum_%'].var()
# Out:
# 286.2485501984998

# %% [markdown]
# #### Find all instances when ‘Snow’ was recorded.

# %%
df2[df2['Weather Condition'] == 'Snow']
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 55       1/3/2012 7:00   -14.0             -19.5         63               19
# 84      1/4/2012 12:00   -13.7             -21.7         51               11
# 86      1/4/2012 14:00   -11.3             -19.0         53                7
# 87      1/4/2012 15:00   -10.2             -16.3         61               11
# 88      1/4/2012 16:00    -9.4             -15.5         61               13
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %% [markdown]
# #### Find all instances when ‘wind speed’ is above 24 and visibility is 25.

# %%
df2[(df2['Wind Speed_km/h'] > 24) & (df2['Visibility_km'] == 25)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 23      1/1/2012 23:00     5.3               2.0         79               30
# 24       1/2/2012 0:00     5.2               1.5         77               35
# 25       1/2/2012 1:00     4.6               0.0         72               39
# 26       1/2/2012 2:00     3.9              -0.9         71               32
# 27       1/2/2012 3:00     3.7              -1.5         69               33
# ...                ...     ...               ...        ...              ...
# 8705  12/28/2012 17:00    -8.6             -12.0         76               26
# 8753  12/30/2012 17:00   -12.1             -15.8         74               28
# 8755  12/30/2012 19:00   -13.4             -16.5         77               26
# 8759  12/30/2012 23:00   -12.1             -15.1         78               28
# 8760   12/31/2012 0:00   -11.1             -14.4         77               26
#
# ...

# %% [markdown]
# #### What is the average value of each column against each ‘weather condition’.

# %%
df2.groupby('Weather Condition').mean(numeric_only=True)
# Out:
#                                             Temp_C  Dew Point Temp_C  \
# Weather Condition
# Clear                                     6.825716          0.089367
# Cloudy                                    7.970544          2.375810
# Drizzle                                   7.353659          5.504878
# Drizzle,Fog                               8.067500          7.033750
# Drizzle,Ice Pellets,Fog                   0.400000         -0.700000
# Drizzle,Snow                              1.050000          0.150000
# Drizzle,Snow,Fog                          0.693333          0.120000
# Fog                                       4.303333          3.159333
# Freezing Drizzle                         -5.657143         -8.000000
# Freezing Drizzle,Fog                     -2.533333         -4.183333
# Freezing Drizzle,Haze                    -5.433333         -8.000000
# Freezing Drizzle,Snow                    -5.109091         -7.072727
# ...

# %% [markdown]
# #### Show all records where weather condition is fog.

# %%
df2[df2['Weather Condition'] == 'Fog']
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# 5        1/1/2012 5:00    -1.4              -3.3         87                9
# 6        1/1/2012 6:00    -1.5              -3.1         89                7
# ...                ...     ...               ...        ...              ...
# 8716   12/29/2012 4:00   -16.0             -17.2         90                6
# 8717   12/29/2012 5:00   -14.8             -15.9         91                4
# 8718   12/29/2012 6:00   -13.8             -15.3         88                4
# 8719   12/29/2012 7:00   -14.8             -16.4         88                7
# 8722  12/29/2012 10:00   -12.0             -13.3         90                7
#
# ...

# %% [markdown]
# #### What is the minimum & maximum value of each column against each ‘weather condition’.

# %%
df2.groupby('Weather Condition').agg(['min', 'max'])
# Out:
#                                                 Date/Time                    \
#                                                       min               max
# Weather Condition
# Clear                                      1/11/2012 1:00     9/9/2012 5:00
# Cloudy                                     1/1/2012 17:00    9/9/2012 23:00
# Drizzle                                   1/23/2012 21:00    9/30/2012 3:00
# Drizzle,Fog                               1/23/2012 20:00    9/30/2012 2:00
# Drizzle,Ice Pellets,Fog                   12/17/2012 9:00   12/17/2012 9:00
# Drizzle,Snow                             12/17/2012 15:00  12/19/2012 18:00
# Drizzle,Snow,Fog                         12/18/2012 21:00   12/22/2012 3:00
# Fog                                         1/1/2012 0:00    9/22/2012 0:00
# Freezing Drizzle                          1/13/2012 10:00     2/1/2012 5:00
# Freezing Drizzle,Fog                        1/1/2012 2:00   12/10/2012 5:00
# ...

# %% [markdown]
# ==========

# %% [markdown]
# # GOOD LUCK!
